# %%
import cv2

# %% [markdown]
# ### Image Manipulation

# %%
img = cv2.imread("opencv.png", cv2.IMREAD_COLOR)

# %% [markdown]
# __flag__ (cv.IMREAD_COLOR 자리)
#
# cv2.IMREAD_COLOR : 이미지 파일을 Color로 읽어들입니다. 투명한 부분은 무시되며, Default값입니다.
#
# cv2.IMREAD_GRAYSCALE : 이미지를 Grayscale로 읽어 들입니다. 실제 이미지 처리시 중간단계로 많이 사용합니다.
#
# cv2.IMREAD_UNCHANGED : 이미지파일을 alpha channel까지 포함하여 읽어 들입니다.

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 이미지 저장

# %%
cv2.imwrite('opencv-copy.png', img)
# Out:
# True

# %% [markdown]
# ### MatPlotLib 이용해서 이미지 띄우기

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('desert.jpg', cv2.IMREAD_COLOR)

plt.imshow(img)
plt.xticks([]) # x축 눈금
plt.yticks([]) # y축 눈금
plt.show()

# %% [markdown]
# 원본은 붉은 계열인데 파란색 계열으로 나온다
#
# 왜냐하면 OpenCV는 BRG, MatPlotLib은 RGB를 쓰기 때문에 첫번째, 세번째 배열의 값을 바꿔야 한다.

# %%
img.shape
# Out:
# (200, 300, 3)

# %%
b, g, r = cv2.split(img)   # img파일을 b,g,r로 분리
img2 = cv2.merge([r,g,b]) # b, r을 바꿔서 Merge

plt.imshow(img2)
plt.xticks([]) # x축 눈금
plt.yticks([]) # y축 눈금
plt.show()
